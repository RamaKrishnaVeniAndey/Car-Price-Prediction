# %%
import pandas as pd
import pickle
import warnings
warnings.filterwarnings("ignore")
data=pd.read_csv("C:/Users/Rama Krishna Veni/Documents/car data.csv")
data.head(10)
# Out:
#    ID   model  engine_power  age_in_days      km  previous_owners        lat  \
# 0   1  lounge            51          882   25000                1  44.907242
# 1   2     pop            51         1186   32500                1  45.666359
# 2   3   sport            74         4658  142228                1  45.503300
# 3   4  lounge            51         2739  160000                1  40.633171
# 4   5     pop            73         3074  106880                1  41.903221
# 5   6     pop            74         3623   70225                1  45.000702
# 6   7  lounge            51          731   11600                1  44.907242
# 7   8  lounge            51         1521   49076                1  41.903221
# 8   9   sport            73         4049   76000                1  45.548000
# 9  10   sport            51         3653   89000                1  45.438301
#
#          lon  price
# 0   8.611560   8900
# 1  12.241890   8800
# 2  11.417840   4200
# 3  17.634609   6000
# 4  12.495650   5700
# 5   7.682270   7900
# 6   8.611560  10750
# 7  12.495650   9190
# 8  11.549470   5600
# 9  10.991700   6000

# %%
data.describe()
# Out:
#                 ID  engine_power  age_in_days             km  previous_owners  \
# count  1538.000000   1538.000000  1538.000000    1538.000000      1538.000000
# mean    769.500000     51.904421  1650.980494   53396.011704         1.123537
# std     444.126671      3.988023  1289.522278   40046.830723         0.416423
# min       1.000000     51.000000   366.000000    1232.000000         1.000000
# 25%     385.250000     51.000000   670.000000   20006.250000         1.000000
# 50%     769.500000     51.000000  1035.000000   39031.000000         1.000000
# 75%    1153.750000     51.000000  2616.000000   79667.750000         1.000000
# max    1538.000000     77.000000  4658.000000  235000.000000         4.000000
#
#                lat          lon         price
# count  1538.000000  1538.000000   1538.000000
# mean     43.541361    11.563428   8576.003901
# std       2.133518     2.328190   1939.958641
# min      36.855839     7.245400   2500.000000
# 25%      41.802990     9.505090   7122.500000
# 50%      44.394096    11.869260   9000.000000
# 75%      45.467960    12.769040  10000.000000
# max      46.795612    18.365520  11100.000000

# %%
data.tail()
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 1533  1534   sport            51         3712  115280                1
# 1534  1535  lounge            74         3835  112000                1
# 1535  1536     pop            51         2223   60457                1
# 1536  1537  lounge            51         2557   80750                1
# 1537  1538     pop            51         1766   54276                1
#
#             lat       lon  price
# 1533  45.069679   7.70492   5200
# 1534  45.845692   8.66687   4600
# 1535  45.481541   9.41348   7500
# 1536  45.000702   7.68227   5990
# 1537  40.323410  17.56827   7900

# %%
data['engine_power'].unique()
# Out:
# array([51, 74, 73, 62, 63, 66, 77, 58], dtype=int64)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1538 entries, 0 to 1537
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               1538 non-null   int64
#  1   model            1538 non-null   object
#  2   engine_power     1538 non-null   int64
#  3   age_in_days      1538 non-null   int64
#  4   km               1538 non-null   int64
#  5   previous_owners  1538 non-null   int64
#  6   lat              1538 non-null   float64
#  7   lon              1538 non-null   float64
#  8   price            1538 non-null   int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 108.3+ KB

# %%
data.groupby(['model']).count()
# Out:
#           ID  engine_power  age_in_days    km  previous_owners   lat   lon  \
# model
# lounge  1094          1094         1094  1094             1094  1094  1094
# pop      358           358          358   358              358   358   358
# sport     86            86           86    86               86    86    86
#
#         price
# model
# lounge   1094
# pop       358
# sport      86

# %%
data.groupby(['previous_owners']).count()
# Out:
#                    ID  model  engine_power  age_in_days    km   lat   lon  \
# previous_owners
# 1                1389   1389          1389         1389  1389  1389  1389
# 2                 117    117           117          117   117   117   117
# 3                  23     23            23           23    23    23    23
# 4                   9      9             9            9     9     9     9
#
#                  price
# previous_owners
# 1                 1389
# 2                  117
# 3                   23
# 4                    9

# %%
data.shape
# Out:
# (1538, 9)

# %%
data=data.drop(['lat','ID'],axis=1)

# %%
data.head(10)
# Out:
#     model  engine_power  age_in_days      km  previous_owners        lon  \
# 0  lounge            51          882   25000                1   8.611560
# 1     pop            51         1186   32500                1  12.241890
# 2   sport            74         4658  142228                1  11.417840
# 3  lounge            51         2739  160000                1  17.634609
# 4     pop            73         3074  106880                1  12.495650
# 5     pop            74         3623   70225                1   7.682270
# 6  lounge            51          731   11600                1   8.611560
# 7  lounge            51         1521   49076                1  12.495650
# 8   sport            73         4049   76000                1  11.549470
# 9   sport            51         3653   89000                1  10.991700
#
#    price
# 0   8900
# 1   8800
# 2   4200
# 3   6000
# 4   5700
# 5   7900
# 6  10750
# 7   9190
# 8   5600
# 9   6000

# %%
data=data.drop(['lon'],axis=1)

# %%
data.head(10)
# Out:
#     model  engine_power  age_in_days      km  previous_owners  price
# 0  lounge            51          882   25000                1   8900
# 1     pop            51         1186   32500                1   8800
# 2   sport            74         4658  142228                1   4200
# 3  lounge            51         2739  160000                1   6000
# 4     pop            73         3074  106880                1   5700
# 5     pop            74         3623   70225                1   7900
# 6  lounge            51          731   11600                1  10750
# 7  lounge            51         1521   49076                1   9190
# 8   sport            73         4049   76000                1   5600
# 9   sport            51         3653   89000                1   6000

# %%
data.shape
# Out:
# (1538, 6)

# %%
data=pd.get_dummies(data,dtype=int)

# %%
data.head(10)
# Out:
#    engine_power  age_in_days      km  previous_owners  price  model_lounge  \
# 0            51          882   25000                1   8900             1
# 1            51         1186   32500                1   8800             0
# 2            74         4658  142228                1   4200             0
# 3            51         2739  160000                1   6000             1
# 4            73         3074  106880                1   5700             0
# 5            74         3623   70225                1   7900             0
# 6            51          731   11600                1  10750             1
# 7            51         1521   49076                1   9190             1
# 8            73         4049   76000                1   5600             0
# 9            51         3653   89000                1   6000             0
#
#    model_pop  model_sport
# 0          0            0
# 1          1            0
# 2          0            1
# 3          0            0
# 4          1            0
# 5          1            0
# 6          0            0
# 7          0            0
# 8          0            1
# 9          0            1

# %%
data.shape
# Out:
# (1538, 8)

# %%
y=data['price']#dependent variables
x=data.drop('price',axis=1)
x.head(10)#independent variables
# Out:
#    engine_power  age_in_days      km  previous_owners  model_lounge  \
# 0            51          882   25000                1             1
# 1            51         1186   32500                1             0
# 2            74         4658  142228                1             0
# 3            51         2739  160000                1             1
# 4            73         3074  106880                1             0
# 5            74         3623   70225                1             0
# 6            51          731   11600                1             1
# 7            51         1521   49076                1             1
# 8            73         4049   76000                1             0
# 9            51         3653   89000                1             0
#
#    model_pop  model_sport
# 0          0            0
# 1          1            0
# 2          0            1
# 3          0            0
# 4          1            0
# 5          1            0
# 6          0            0
# 7          0            0
# 8          0            1
# 9          0            1

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)
x_test.head(10)
# Out:
#       engine_power  age_in_days      km  previous_owners  model_lounge  \
# 481             51         3197  120000                2             0
# 76              62         2101  103000                1             0
# 1502            51          670   32473                1             1
# 669             51          913   29000                1             1
# 1409            51          762   18800                1             1
# 1414            51          762   39751                1             1
# 1089            51          882   33160                1             1
# 1507            51          701   17324                1             1
# 970             51          701   29000                1             1
# 1198            51         1155   38000                1             1
#
#       model_pop  model_sport
# 481           1            0
# 76            1            0
# 1502          0            0
# 669           0            0
# 1409          0            0
# 1414          0            0
# 1089          0            0
# 1507          0            0
# 970           0            0
# 1198          0            0

# %%
x_train.head(10)
# Out:
#       engine_power  age_in_days     km  previous_owners  model_lounge  \
# 527             51          425  13111                1             1
# 129             51         1127  21400                1             1
# 602             51         2039  57039                1             0
# 331             51         1155  40700                1             1
# 323             51          425  16783                1             1
# 1358            51          762  29378                1             1
# 522             51          425  18443                1             1
# 584             51          397  11997                1             1
# 1236            51         2162  66900                1             1
# 535             51          609  35000                1             0
#
#       model_pop  model_sport
# 527           0            0
# 129           0            0
# 602           1            0
# 331           0            0
# 323           0            0
# 1358          0            0
# 522           0            0
# 584           0            0
# 1236          0            0
# 535           0            1

# %%
y.head(10)
# Out:
# 0     8900
# 1     8800
# 2     4200
# 3     6000
# 4     5700
# 5     7900
# 6    10750
# 7     9190
# 8     5600
# 9     6000
# Name: price, dtype: int64

# %%
y_train.shape
# Out:
# (1030,)

# %%
x_train.shape
# Out:
# (1030, 7)

# %%
y_test.head(10)
# Out:
# 481      7900
# 76       7900
# 1502     9400
# 669      8500
# 1409     9700
# 1414     9900
# 1089     9900
# 1507     9950
# 970     10700
# 1198     8999
# Name: price, dtype: int64

# %%
y_train.head(10)
# Out:
# 527      9990
# 129      9500
# 602      7590
# 331      8750
# 323      9100
# 1358    10900
# 522     10800
# 584      9999
# 1236     8500
# 535     10500
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ypred=reg.predict(x_test)
ypred
# Out:
# array([ 5867.6503378 ,  7133.70142341,  9866.35776216,  9723.28874535,
#        10039.59101162,  9654.07582608,  9673.14563045, 10118.70728123,
#         9903.85952664,  9351.55828437, 10434.34963575,  7732.26255693,
#         7698.67240131,  6565.95240435,  9662.90103518, 10373.20344286,
#         9599.94844451,  7699.34400418,  4941.33017994, 10455.2719478 ,
#        10370.51555682, 10391.60424404,  7529.06622456,  9952.37340054,
#         7006.13845729,  9000.1780961 ,  4798.36770637,  6953.10376491,
#         7810.39767825,  9623.80497535,  7333.52158317,  5229.18705519,
#         5398.21541073,  5157.65652129,  8948.63632836,  5666.62365159,
# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(x='ID',y='price',data=results.loc[100:150])

sns.lineplot(x='ID',y='predicted',data=results.loc[100:150])
plt.plot()
# Out:
# []

# %%
#this for prediction of a new vehicle with specific
list=[[51,2500,70000,1,1,0,0]]
real=reg.predict(list)
real
# Out:
# array([7617.13028412])

# %%
list=[[76,3000,50000,1,1,0,0],[51,2500,70000,1,0,1,0],[50,2000,80000,1,0,0,1]]
real=reg.predict(list)
real
# Out:
# array([7815.86262496, 7288.18007138, 7639.02850167])

# %%
cor_mat=data.corr()
cor_mat
# Out:
#                  engine_power  age_in_days        km  previous_owners  \
# engine_power         1.000000     0.319190  0.285495        -0.005030
# age_in_days          0.319190     1.000000  0.833890         0.075775
# km                   0.285495     0.833890  1.000000         0.097539
# previous_owners     -0.005030     0.075775  0.097539         1.000000
# price               -0.277235    -0.893328 -0.859373        -0.076274
# model_lounge        -0.133321    -0.259863 -0.255746        -0.024643
# model_pop            0.024783     0.108327  0.109024        -0.019316
# model_sport          0.217362     0.313276  0.303874         0.084129
#
#                     price  model_lounge  model_pop  model_sport
# engine_power    -0.277235     -0.133321   0.024783     0.217362
# age_in_days     -0.893328     -0.259863   0.108327     0.313276
# km              -0.859373     -0.255746   0.109024     0.303874
# previous_owners -0.076274     -0.024643  -0.019316     0.084129
# price            1.000000      0.302299  -0.167190    -0.288706
# model_lounge     0.302299      1.000000  -0.864605    -0.382017
# model_pop       -0.167190     -0.864605   1.000000    -0.134050
# model_sport     -0.288706     -0.382017  -0.134050     1.000000

# %%
sns.heatmap(cor_mat,annot=True,linewidths=5,cmap='bwr')
# Out:
# <Axes: >

# %%
#ridge regression

# %%
from sklearn.model_selection import GridSearchCV
#from sklearn.grid_search import GridSearchCV


from sklearn.linear_model import Ridge

alpha = [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20,30]

ridge = Ridge()

parameters = {'alpha': alpha}

ridge_regressor = GridSearchCV(ridge, parameters)

ridge_regressor.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.0001, 0.001, 0.01, 1,
#                                    5, 10, 20, 30]})

# %%
ridge_regressor.best_params_
# Out:
# {'alpha': 30}

# %%
#X_train=[2]

# %%
ridge=Ridge(alpha=30)
ridge.fit(x_train,y_train)
y_pred_ridge=ridge.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
Ridge_Error=mean_squared_error(y_pred_ridge,y_test)
Ridge_Error
# Out:
# 579521.7970897452

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred_ridge)
# Out:
# 0.8421969385523054

# %%
Results= pd.DataFrame(columns=['Actual','Predicted'])
Results['Actual']=y_test
Results['Predicted']=y_pred_ridge
#Results['km']=X_test['km']
Results=Results.reset_index()
Results['Id']=Results.index
Results.head(10)
# Out:
#    index  Actual     Predicted  Id
# 0    481    7900   5869.741155   0
# 1     76    7900   7149.563327   1
# 2   1502    9400   9862.785355   2
# 3    669    8500   9719.283532   3
# 4   1409    9700  10035.895686   4
# 5   1414    9900   9650.311090   5
# 6   1089    9900   9669.183317   6
# 7   1507    9950  10115.128380   7
# 8    970   10700   9900.241944   8
# 9   1198    8999   9347.080772   9

# %%
sns.lineplot(x='Id',y='Actual',data=Results.head(50))
sns.lineplot(x='Id',y='Predicted',data=Results.head(50))
plt.plot()
# Out:
# []

# %%
sns.lineplot(x='Id',y='Actual',data=Results.tail(50))
sns.lineplot(x='Id',y='Predicted',data=Results.tail(50))
plt.plot()
# Out:
# []

# %%
#elastic

# %%
from sklearn.linear_model import ElasticNet

elastic = ElasticNet()

parameters = {'alpha': [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20]}

elastic_regressor = GridSearchCV(elastic, parameters)

elastic_regressor.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=ElasticNet(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.0001, 0.001, 0.01, 1,
#                                    5, 10, 20]})

# %%
elastic_regressor.best_params_
# Out:
# {'alpha': 0.01}

# %%
elastic=ElasticNet(alpha=.01)
elastic.fit(x_train,y_train)
y_pred_elastic=elastic.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred_elastic)
# Out:
# 0.841688021120299

# %%
elastic_Error=mean_squared_error(y_pred_elastic,y_test)
elastic_Error
# Out:
# 581390.7642825295

# %%
Results= pd.DataFrame(columns=['Actual','Predicted'])
Results['Actual']=y_test
Results['Predicted']=y_pred_elastic
#Results['km']=X_test['km']
Results=Results.reset_index()
Results['Id']=Results.index
Results.head(10)
# Out:
#    index  Actual     Predicted  Id
# 0    481    7900   5867.742075   0
# 1     76    7900   7136.527402   1
# 2   1502    9400   9865.726723   2
# 3    669    8500   9722.573593   3
# 4   1409    9700  10038.936496   4
# 5   1414    9900   9653.407122   5
# 6   1089    9900   9672.438692   6
# 7   1507    9950  10118.075470   7
# 8    970   10700   9903.219809   8
# 9   1198    8999   9350.750929   9

# %%
sns.lineplot(x='Id',y='Actual',data=Results.head(50))
sns.lineplot(x='Id',y='Predicted',data=Results.head(50))
plt.plot()
# Out:
# []

# %%
#RandomForest

# %%
from sklearn.model_selection import GridSearchCV #GridSearchCV is for parameter tuning
from sklearn.ensemble import RandomForestRegressor
reg=RandomForestRegressor()
n_estimators=[25,50,75,100,125,150,175,200] #number of decision trees in the forest, default = 100
criterion=['squared_error'] #criteria for choosing nodes default = 'gini'
max_depth=[3,5,10] #maximum number of nodes in a tree default = None (it will go till all possible nodes)
parameters={'n_estimators': n_estimators,'criterion':criterion,'max_depth':max_depth}  
RFC_reg = GridSearchCV(reg, parameters)
RFC_reg.fit(x_train,y_train)

# %%
RFC_reg.best_params_
# Out:
# {'criterion': 'squared_error', 'max_depth': 5, 'n_estimators': 50}

# %%
reg=RandomForestRegressor(n_estimators=125,criterion='squared_error',max_depth=5)

# %%
reg.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=5, n_estimators=125)

# %%
y_pred=reg.predict(x_test)

# %%
y_pred
# Out:
# array([ 5971.89103598,  7129.57632037,  9808.51972655,  9753.8231147 ,
#        10057.07100266,  9633.57699974,  9715.48321825, 10072.70856664,
#         9834.38182835,  9412.24245068, 10364.50067866,  7796.00471   ,
#         7366.46307583,  7089.55922423,  9548.46490671, 10433.61094012,
#         9699.36229292,  7772.97012956,  5014.23641226, 10364.87674805,
#        10159.72406779, 10437.74517963,  7501.30529085,  9792.66137169,
#         7438.22221737,  8993.09830238,  4782.58370868,  7027.91249722,
#         7680.82813138,  9574.9690456 ,  7113.71092407,  5153.90548112,
#         5465.25216176,  5054.59824111,  8629.6961646 ,  5414.3272493 ,
#        10181.7070511 ,  7441.21368968,  6543.67176479,  8925.19054484,
#         9778.18811178,  6880.54543837,  9478.43336083, 10340.08685302,
#        10121.60129278,  9849.8657665 ,  8885.03264633,  7810.31199842,
#        10377.77071384,  5854.09618486,  9795.69333221, 10127.55835746,
#        10444.75892142,  9588.80801049,  9603.76832555,  9681.00168456,
#         5429.88359379,  5421.29012432,  5211.66192199,  9746.91097909,
#         5993.88278674,  9795.69333221, 10086.6457836 ,  5071.50932999,
#         7866.5398792 ,  9807.05190238,  5488.76549897, 10436.38032107,
#         5315.75255987,  9625.0807907 , 10072.70856664, 10121.82202297,
#         9675.75014602,  5079.70256076,  5748.10096061,  7842.89346729,
#         9818.13234807, 10436.38032107,  9834.38182835,  7458.8745414 ,
#         8675.66546766,  9917.82453916, 10436.73658552,  9808.51972655,
#         8210.17975571,  9840.32762376,  8503.76127178,  9772.35861914,
#         9792.07055542,  9778.36307291,  7277.17407698,  7212.55782465,
#         8926.40080952,  9829.51237214,  9807.05190238, 10361.60527013,
#         7863.52700978,  7088.3835828 ,  9823.33688937,  8847.17818192,
#         9792.66137169, 10156.19541325, 10114.35042336, 10076.06449758,
#         9041.67453106, 10038.67414984,  9108.55797108, 10070.81898669,
#         7504.24335836,  5848.78598242,  8646.408578  , 10075.58891483,
#         5322.37471072, 10193.86709239,  9565.66809689,  7858.34012503,
#         9353.04761592,  7148.36383502, 10447.43815671, 10065.14581579,
#        10383.68966521,  9833.85463026, 10086.6457836 ,  6541.97015689,
#        10446.4845836 ,  9823.33688937, 10424.7968415 , 10035.06213684,
#         9605.0120546 ,  6242.94394911,  7867.7885946 , 10443.63630317,
#         6099.68324479,  7239.95246472,  9819.77011741,  7044.22922738,
#         7854.31401782,  5299.95029838,  4762.28079522,  8456.97812119,
#         7099.20468502,  7112.7661592 ,  7096.55702563,  7008.42276573,
#         9853.06822537,  8675.66546766,  9501.78846197, 10441.88613033,
#        10193.86709239, 10441.88613033,  9772.35861914,  5591.47797378,
#         9649.81723295,  7130.53238383,  5316.37315218,  4886.44434129,
#         9808.51972655,  9294.26855731, 10076.06449758,  6178.48538743,
#         8458.34501816, 10435.9662689 ,  5009.90741081,  9979.27567638,
#         6225.30453183, 10069.02955308,  8440.85937488, 10433.61094012])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.8447437337402048

# %%
Results= pd.DataFrame(columns=['Actual','Predicted'])
Results['Actual']=y_test
Results['Predicted']=y_pred
#Results['km']=X_test['km']
Results=Results.reset_index()
Results['Id']=Results.index
Results.head(10)
# Out:
#    index  Actual     Predicted  Id
# 0    481    7900   5971.891036   0
# 1     76    7900   7129.576320   1
# 2   1502    9400   9808.519727   2
# 3    669    8500   9753.823115   3
# 4   1409    9700  10057.071003   4
# 5   1414    9900   9633.577000   5
# 6   1089    9900   9715.483218   6
# 7   1507    9950  10072.708567   7
# 8    970   10700   9834.381828   8
# 9   1198    8999   9412.242451   9

# %%
sns.lineplot(x='Id',y='Actual',data=Results.head(100))
sns.lineplot(x='Id',y='Predicted',data=Results.head(100))
plt.plot()
# Out:
# []

# %%
# !python --version
# Out:
# Python 3.11.5
